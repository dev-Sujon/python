# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sns
# Out:
# <module 'seaborn' from '/home/sujon/anaconda3/lib/python3.11/site-packages/seaborn/__init__.py'>

# %%
pd
# Out:
# <module 'pandas' from '/home/sujon/anaconda3/lib/python3.11/site-packages/pandas/__init__.py'>

# %%
np
# Out:
# <module 'numpy' from '/home/sujon/anaconda3/lib/python3.11/site-packages/numpy/__init__.py'>

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/sujon/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py'>

# %%
var=[1,2,3,4,5,6,7]
var_1=[2,3,4,5,1,6,7]
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(var,var_1)

# %%
x_1=pd.DataFrame({"var":var,"var-1":var_1})

# %%
sns.lineplot(data=x_1)
plt.xlabel("var")
plt.ylabel("var_1")
# Out:
# Text(0, 0.5, 'var_1')

# %%
sns.lineplot(var_1)
# Out:
# <Axes: >

# %%
#load data using seaborn

# %%
xData=sns.load_dataset("penguins")
xData
