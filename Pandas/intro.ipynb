# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("student_data.csv")

# %%
dataset
# Out:
#      schoolid                 schoolname  CalendarYear  MainOPEID  SchoolCity  \
# 0      100300        Faulkner University          2022     100300  Montgomery
# 1      103600         Samford University          2022     103600  Birmingham
# 2      105100      University of Alabama          2022     105100  Tuscaloosa
# 3      108100   Arizona State University          2022     108100   Phoenix\n
# 4      108300      University of Arizona          2022     108300      Tucson
# ..        ...                        ...           ...        ...         ...
# 205   3691400    Ave Maria School of Law          2022    3691400      Naples
# 206   4096300   Charleston School of Law          2022    4096300  Charleston
# 207   4131400  Arizona Summit Law School          2022    4131400     Phoenix
# 208   4143500    Charlotte School of Law          2022    4143500   Charlotte
# 209   4242101  UNT Dallas College Of Law          2022    4242100      Dallas
#
# ...

# %%
df=pd.DataFrame(dataset)

# %%
df
# Out:
#      schoolid                 schoolname  CalendarYear  MainOPEID  SchoolCity  \
# 0      100300        Faulkner University          2022     100300  Montgomery
# 1      103600         Samford University          2022     103600  Birmingham
# 2      105100      University of Alabama          2022     105100  Tuscaloosa
# 3      108100   Arizona State University          2022     108100   Phoenix\n
# 4      108300      University of Arizona          2022     108300      Tucson
# ..        ...                        ...           ...        ...         ...
# 205   3691400    Ave Maria School of Law          2022    3691400      Naples
# 206   4096300   Charleston School of Law          2022    4096300  Charleston
# 207   4131400  Arizona Summit Law School          2022    4131400     Phoenix
# 208   4143500    Charlotte School of Law          2022    4143500   Charlotte
# 209   4242101  UNT Dallas College Of Law          2022    4242100      Dallas
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   schoolid       210 non-null    int64
#  1   schoolname     210 non-null    object
#  2   CalendarYear   210 non-null    int64
#  3   MainOPEID      210 non-null    int64
#  4   SchoolCity     209 non-null    object
#  5   SchoolState    210 non-null    object
#  6   SchoolZipCode  209 non-null    object
#  7   TermType       210 non-null    object
#  8   SchoolType     210 non-null    object
#  9   SchoolStatus   210 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 16.5+ KB

# %%
df.describe()
# Out:
#            schoolid  CalendarYear     MainOPEID
# count  2.100000e+02         210.0  2.100000e+02
# mean   4.737353e+05        2022.0  4.750915e+05
# std    7.717196e+05           0.0  7.718858e+05
# min    1.003000e+05        2022.0  1.003000e+05
# 25%    1.774250e+05        2022.0  1.774250e+05
# 50%    2.692055e+05        2022.0  2.692000e+05
# 75%    3.524750e+05        2022.0  3.524750e+05
# max    4.242101e+06        2022.0  4.242100e+06

# %%
df.schoolid
# Out:
# 0       100300
# 1       103600
# 2       105100
# 3       108100
# 4       108300
#         ...
# 205    3691400
# 206    4096300
# 207    4131400
# 208    4143500
# 209    4242101
# Name: schoolid, Length: 210, dtype: int64

# %%
df.iloc[200]
# Out:
# schoolid                   3091300
# schoolname       Regent University
# CalendarYear                  2022
# MainOPEID                  3091300
# SchoolCity          Virginia Beach
# SchoolState                     VA
# SchoolZipCode                23464
# TermType                       SEM
# SchoolType                     PRI
# SchoolStatus                Active
# Name: 200, dtype: object

# %%
df
# Out:
#      schoolid                 schoolname  CalendarYear  MainOPEID  SchoolCity  \
# 0      100300        Faulkner University          2022     100300  Montgomery
# 1      103600         Samford University          2022     103600  Birmingham
# 2      105100      University of Alabama          2022     105100  Tuscaloosa
# 3      108100   Arizona State University          2022     108100   Phoenix\n
# 4      108300      University of Arizona          2022     108300      Tucson
# ..        ...                        ...           ...        ...         ...
# 205   3691400    Ave Maria School of Law          2022    3691400      Naples
# 206   4096300   Charleston School of Law          2022    4096300  Charleston
# 207   4131400  Arizona Summit Law School          2022    4131400     Phoenix
# 208   4143500    Charlotte School of Law          2022    4143500   Charlotte
# 209   4242101  UNT Dallas College Of Law          2022    4242100      Dallas
#
# ...

# %%
df.loc[100]
# Out:
# schoolid                            262901
# schoolname       Rutgers University-Camden
# CalendarYear                          2022
# MainOPEID                           262900
# SchoolCity                          Camden
# SchoolState                             NJ
# SchoolZipCode                        08102
# TermType                               SEM
# SchoolType                             PUB
# SchoolStatus                      InActive
# Name: 100, dtype: object

# %%
df.head()
# Out:
#    schoolid                schoolname  CalendarYear  MainOPEID  SchoolCity  \
# 0    100300       Faulkner University          2022     100300  Montgomery
# 1    103600        Samford University          2022     103600  Birmingham
# 2    105100     University of Alabama          2022     105100  Tuscaloosa
# 3    108100  Arizona State University          2022     108100   Phoenix\n
# 4    108300     University of Arizona          2022     108300      Tucson
#
#   SchoolState SchoolZipCode TermType SchoolType SchoolStatus
# 0          AL         36109      SEM        PRI       Active
# 1          AL         35229      SEM        PRI       Active
# 2          AL         35487      SEM        PUB       Active
# 3          AZ     850044467      SEM        PUB       Active
# 4          AZ       85721\n      SEM        PUB       Active

# %%
df.tail(50)
# Out:
#      schoolid                                schoolname  CalendarYear  \
# 160    361300             Southern Methodist University          2022
# 161    362300                     St. Mary's University          2022
# 162    363221                      Texas A&M University          2022
# 163    364200                 Texas Southern University          2022
# 164    364400                     Texas Tech University          2022
# 165    365200                     University of Houston          2022
# 166    365800             University of Texas at Austin          2022
# 167    367000                  Brigham Young University          2022
# 168    367500                        University of Utah          2022
# 169    370500               William and Mary Law School          2022
# 170    374400                    University of Richmond          2022
# 171    374500                    University of Virginia          2022
# ...

# %% [markdown]
# # new csv file is included

# %%
dff=pd.read_csv("matches.csv")

# %%
dff
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
np
# Out:
# <module 'numpy' from '/home/sujon/anaconda3/lib/python3.11/site-packages/numpy/__init__.py'>

# %%
dff[:-1]
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 630  631    2016    Kolkata  2016-05-22        Kolkata Knight Riders
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
dff[2:]
# Out:
#       id  season       city        date                        team1  \
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
dff.head() #its a function to use to data preview
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
dff.tail(10) #its a function to use to data preview
# Out:
#       id  season           city        date                  team1  \
# 626  627    2016         Kanpur  2016-05-19  Kolkata Knight Riders
# 627  628    2016         Raipur  2016-05-20    Sunrisers Hyderabad
# 628  629    2016  Visakhapatnam  2016-05-21        Kings XI Punjab
# 629  630    2016         Kanpur  2016-05-21         Mumbai Indians
# 630  631    2016        Kolkata  2016-05-22  Kolkata Knight Riders
# 631  632    2016         Raipur  2016-05-22       Delhi Daredevils
# 632  633    2016      Bangalore  2016-05-24          Gujarat Lions
# 633  634    2016          Delhi  2016-05-25    Sunrisers Hyderabad
# 634  635    2016          Delhi  2016-05-27          Gujarat Lions
# 635  636    2016      Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 626                Gujarat Lions                Gujarat Lions         field
# ...

# %%
dff.tail(1)
# Out:
#       id  season       city        date                team1  \
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2          toss_winner toss_decision  result  \
# 635  Royal Challengers Bangalore  Sunrisers Hyderabad           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 635           0  Sunrisers Hyderabad            8               0
#
#     player_of_match                  venue          umpire1       umpire2  \
# 635     BCJ Cutting  M Chinnaswamy Stadium  HDPK Dharmasena  BNJ Oxenford
#
#      umpire3
# 635      NaN

# %%
# how many rows and columns in a dataset

# %%
dff.shape
# Out:
# (636, 18)

# %%
dff.shape[0]
# Out:
# 636

# %%
dff.shape[1]
# Out:
# 18

# %%
# info function

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
dff.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
dff['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
dff['umpire1']
# Out:
# 0          AY Dandekar
# 1       A Nand Kishore
# 2          Nitin Menon
# 3         AK Chaudhary
# 4                  NaN
#             ...
# 631     A Nand Kishore
# 632       AK Chaudhary
# 633          M Erasmus
# 634          M Erasmus
# 635    HDPK Dharmasena
# Name: umpire1, Length: 636, dtype: object

# %%
dff["umpire2"]
# Out:
# 0             NJ Llong
# 1               S Ravi
# 2            CK Nandan
# 3        C Shamshuddin
# 4                  NaN
#             ...
# 631       BNJ Oxenford
# 632    HDPK Dharmasena
# 633      C Shamshuddin
# 634          CK Nandan
# 635       BNJ Oxenford
# Name: umpire2, Length: 636, dtype: object

# %%
dff['umpire1']
# Out:
# 0          AY Dandekar
# 1       A Nand Kishore
# 2          Nitin Menon
# 3         AK Chaudhary
# 4                  NaN
#             ...
# 631     A Nand Kishore
# 632       AK Chaudhary
# 633          M Erasmus
# 634          M Erasmus
# 635    HDPK Dharmasena
# Name: umpire1, Length: 636, dtype: object

# %%
# How to fatch multiple colunms

# %%
dff[["date","team1","team2","winner","result","city"]]
# Out:
#            date                        team1                        team2  \
# 0    2017-04-05          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1    2017-04-06               Mumbai Indians       Rising Pune Supergiant
# 2    2017-04-07                Gujarat Lions        Kolkata Knight Riders
# 3    2017-04-08       Rising Pune Supergiant              Kings XI Punjab
# 4    2017-04-08  Royal Challengers Bangalore             Delhi Daredevils
# ..          ...                          ...                          ...
# 631  2016-05-22             Delhi Daredevils  Royal Challengers Bangalore
# 632  2016-05-24                Gujarat Lions  Royal Challengers Bangalore
# 633  2016-05-25          Sunrisers Hyderabad        Kolkata Knight Riders
# 634  2016-05-27                Gujarat Lions          Sunrisers Hyderabad
# 635  2016-05-29          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner  result       city
# ...

# %%
dff[["date","team1","team2","winner","result","city"]].shape
# Out:
# (636, 6)

# %%
dff[["result"]].shape
# Out:
# (636, 1)

# %%
# fatch rows

# %%
dff.iloc[0]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
dff.iloc[:3]
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
dff.iloc[1,2]
# Out:
# 'Pune'

# %%
dff.iloc[:,[4,5,10]]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
ser = pd.Series(pd.date_range("2000", periods=2, tz="CET"))

# %%
ser
# Out:
# 0   2000-01-01 00:00:00+01:00
# 1   2000-01-02 00:00:00+01:00
# dtype: datetime64[ns, CET]

# %%
dff
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# delete a particular columns and rows

# %%
dff.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Length: 636, dtype: bool
