# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
from statsmodels import robust

# %%
habersman=pd.read_csv("haberman_csv.csv")

# %%
habersman.head()
# Out:
#    Age_of_patient_at_time_of_operation  Patients_year_of_operation  \
# 0                                   30                          64
# 1                                   30                          62
# 2                                   30                          65
# 3                                   31                          59
# 4                                   31                          65
#
#    Number_of_positive_axillary_nodes_detected  Survival_status
# 0                                           1                1
# 1                                           3                1
# 2                                           0                1
# 3                                           2                1
# 4                                           4                1

# %%
habersman.tail(10)
# Out:
#      Age_of_patient_at_time_of_operation  Patients_year_of_operation  \
# 296                                   72                          67
# 297                                   73                          62
# 298                                   73                          68
# 299                                   74                          65
# 300                                   74                          63
# 301                                   75                          62
# 302                                   76                          67
# 303                                   77                          65
# 304                                   78                          65
# 305                                   83                          58
#
#      Number_of_positive_axillary_nodes_detected  Survival_status
# 296                                           3                1
# 297                                           0                1
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(habersman['Age_of_patient_at_time_of_operation'].value_count())
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'
