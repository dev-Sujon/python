# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
#         Exploratory Data Analysis (EDA) is a technique to analyze data using some visual Techniques. With this technique, we can get detailed information about the statistical summary of the data. We will also be able to deal with the duplicates values, outliers, and also see some trends or patterns present in the dataset.

# %%
#Import importent library
import seaborn as sns
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
#3D visualization
import plotly.express as px

# %%
# read csv file

# %%
data=pd.read_csv("iris.csv")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Preview of Data

# %%
data.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
data.shape
# Out:
# (150, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Checking Missing Values
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# no missing value here

# %% [markdown]
# Checking Duplicates
#
# dataset contains any duplicates or not. Pandas drop_duplicates() method helps in removing duplicates from the data frame.

# %%
#first convert dataset to a new DataFrame
df=pd.DataFrame(data)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
dp=df.drop_duplicates(subset="species")
dp.shape
# Out:
# (3, 5)

# %%
# Lets see the dataset is balanced or not

# %%
df.value_counts("species")
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
Visualizing the target column
# Out:
#   Cell In[18], line 1
#     Visualizing the target column
#                 ^
# SyntaxError: invalid syntax

# %%
sns.countplot(x="species",data=df)
plt.show()

# %%
sns.pairplot(df, hue='species', markers='*')
plt.show()

# %%
sns.violineplot(y='species',x='sepla_length',y='sepal width')
plt.show()
# Out:
#   Cell In[21], line 1
#     sns.violineplot(y='species',x='sepla_length',y='sepal width')
#                                                  ^
# SyntaxError: keyword argument repeated: y

# %%
g = sns.violinplot(y='species', x='sepal_length', data=data, inner='quartile')
plt.show()
g = sns.violinplot(y='Species', x='sepal_width', data=data, inner='quartile')
plt.show()
g = sns.violinplot(y='Species', x='petal_length', data=data, inner='quartile')
plt.show()
g = sns.violinplot(y='Species', x='sepal_width', data=data, inner='quartile')
plt.show()

# %%
sns.violinplot(df,x='sepal_length',y='sepal_width',)

# %%
sns.violinplot(x="sepal_length",y="sepal_width",data=df,inner='quartile')
plt.show()

# %%
df

# %% [markdown]
# # Visualizing statistical relationships

# %% [markdown]
# relplot

# %%
df.head(2)

# %%
sns.relplot(data=df,x="species",y="sepal_length",hue='species')

# %%
sns.relplot(data=df,x="species",y="sepal_width",hue='species')

# %%
sns.FacetGrid(df,hue="species") \
    .map(sns.distplot,"petal_width") \
    .add_legend();

# %%
sns.FacetGrid(df,hue='species').map(sns.distplot,"petal_length").add_legend() 
plt.show()

# %%
fig = plt.figure(figsize = (15,9))
sns.heatmap(df.corr(), cmap='Blues', annot = True);

# %% [markdown]
# # Modeling with scikit-learn¶

# %%
#knn classifier library
from sklearn.neighbors import KNeighborsClassifier
# separate dataset to two distinct value to training and testing the dataset
from sklearn.model_selection import train_test_split
#import sklearn matric to check accuracy score
from sklearn.metrics import accuracy_score

# %%
#initialize the knn object
neigh= KNeighborsClassifier()

# %% [markdown]
# # Preprocess the Dataset

# %%
X=df[['sepal_length','sepal_width','sepal_length','sepal_width']]
Y=df['species']

# %% [markdown]
# # Train and test on the same dataset

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.20,random_state=40)

# %%
X_train.tail()
# Out:
#     sepal_length  sepal_width  sepal_length  sepal_width
# 71           6.1          2.8           6.1          2.8
# 12           4.8          3.0           4.8          3.0
# 50           7.0          3.2           7.0          3.2
# 7            5.0          3.4           5.0          3.4
# 70           5.9          3.2           5.9          3.2

# %%
X_test.head()
# Out:
#      sepal_length  sepal_width  sepal_length  sepal_width
# 38            4.4          3.0           4.4          3.0
# 66            5.6          3.0           5.6          3.0
# 115           6.4          3.2           6.4          3.2
# 117           7.7          3.8           7.7          3.8
# 89            5.5          2.5           5.5          2.5

# %%
y_train.head()
# Out:
# 62    versicolor
# 23        setosa
# 26        setosa
# 48        setosa
# 2         setosa
# Name: species, dtype: object

# %%
y_test.head()
# Out:
# 38         setosa
# 66     versicolor
# 115     virginica
# 117     virginica
# 89     versicolor
# Name: species, dtype: object

# %%
# to understand the train test split . print out the size
print("X_train : ",X_train.shape)
print("X_test : ",X_test.shape)
print("y_train : ",y_train.shape)
print("y_test : ",y_test.shape)
# Out:
# X_train :  (120, 4)
# X_test :  (30, 4)
# y_train :  (120,)
# y_test :  (30,)

# %%
# Training the dataset
# neigh.fit(X_train,X_train)
# neigh.fit(X_train,X_test)
# this is the right way to write
neigh.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 5
#       1 # Training the dataset
#       2 # neigh.fit(X_train,X_train)
#       3 # neigh.fit(X_train,X_test)
#       4 # this is the right way to write
# ----> 5 neigh.fit(X_train,y_train)
#
# NameError: name 'neigh' is not defined

# %%
y_pred_test=neigh.predict(X_test)
y_pred_train=neigh.predict(X_train)

# %%
y_pred_test

# %%
# check accuracy test

# %%
acc=accuracy_score(y_pred_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 acc=accuracy_score(y_pred_test,y_test)
#
# NameError: name 'accuracy_score' is not defined

# %%
acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 acc
#
# NameError: name 'acc' is not defined

# %%
y_pred_test=list(y_pred_test)
y_pred_train=list(y_pred_train)
y_test=list(y_test)
y_train=list(y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 y_pred_test=list(y_pred_test)
#       2 y_pred_train=list(y_pred_train)
#       3 y_test=list(y_test)
#
# NameError: name 'y_pred_test' is not defined

# %%
for i in range(len(y_test)):
    if y_pred_test[i]==y_test[i]:
        print(y_pred_test[i],y_test[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 for i in range(len(y_test)):
# ----> 2     if y_pred_test[i]==y_test[i]:
#       3         print(y_pred_test[i],y_test[i])
#
# NameError: name 'y_pred_test' is not defined

# %%
for i in range(1,25):
    neigh = KNeighborsClassifier(n_neighbors=i)
    neigh.fit(X_train, y_train)
    y_prediction = neigh.predict(X_test)
    from sklearn.metrics import accuracy_score
    acc = accuracy_score(y_prediction,y_test)
    print('for ',i,'accuracy is',acc)
# Out:
# for  1 accuracy is 0.8666666666666667
# for  2 accuracy is 0.8
# for  3 accuracy is 0.8333333333333334
# for  4 accuracy is 0.7666666666666667
# for  5 accuracy is 0.9
# for  6 accuracy is 0.8666666666666667
# for  7 accuracy is 0.9333333333333333
# for  8 accuracy is 0.9
# for  9 accuracy is 0.9
# for  10 accuracy is 0.8666666666666667
# for  11 accuracy is 0.9
# for  12 accuracy is 0.8
# for  13 accuracy is 0.9
# for  14 accuracy is 0.8333333333333334
# for  15 accuracy is 0.8333333333333334
# for  16 accuracy is 0.8333333333333334
# for  17 accuracy is 0.8333333333333334
# for  18 accuracy is 0.8
# for  19 accuracy is 0.8
# for  20 accuracy is 0.8
# for  21 accuracy is 0.8333333333333334
# for  22 accuracy is 0.8
# for  23 accuracy is 0.8333333333333334
# for  24 accuracy is 0.8333333333333334

# %%
for i in range(3,15):
    
    # Initialization
    neigh = KNeighborsClassifier(n_neighbors=i,weights = 'uniform',p = 3,n_jobs = -1)
    
    # Training
    neigh.fit(X_train, y_train)
    
    # Prediction
    y_prediction_test = neigh.predict(X_test)
    y_prediction_train = neigh.predict(X_train)

    
    acc_test = accuracy_score(y_prediction_test,y_test)
    print('for ',i,'accuracy  test data is',acc_test)
    
    acc_train = accuracy_score(y_prediction_train,y_train)
    print('for ',i,'accuracy  train data is',acc_train)
    
    print('*'*182)
# Out:
# for  3 accuracy  test data is 0.8333333333333334
# for  3 accuracy  train data is 0.8333333333333334
# **************************************************************************************************************************************************************************************
# for  4 accuracy  test data is 0.7333333333333333
# for  4 accuracy  train data is 0.8
# **************************************************************************************************************************************************************************************
# for  5 accuracy  test data is 0.9
# for  5 accuracy  train data is 0.8083333333333333
# **************************************************************************************************************************************************************************************
# for  6 accuracy  test data is 0.9
# for  6 accuracy  train data is 0.7916666666666666
# ...
