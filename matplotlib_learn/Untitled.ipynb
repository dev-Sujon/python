# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
x=np.random.randn(10)
y=np.sin(x)

plt.figure(figsize=(10,8))
plt.title("Keykoslospons")
plt.plot(x,y)

# %%
year=[2006+i for i in range(10)]
weight=[85,80,70,75,83,85,80,70,75,83]
year
# Out:
# [2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015]

# %%
plt.plot(year,weight,"b",lw=3)
plt.show()

# %%
plt.bar(year,weight,color="#000",edgecolor="c",lw=1.2)
plt.show()
